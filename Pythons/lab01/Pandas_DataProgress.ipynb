# %%
import pandas as pd
import seaborn as sb
import numpy as np

# %%
t1 = pd.read_csv("./DemoCSV_01.csv")
t1.head()
# Out:
#    Count        realx      realy        EyeX        EyeY    HeadPosX  \
# 0      0  1430.355591  469.63623  936.891296  411.656555  337.998352
# 1      0  1430.355591  469.63623  936.891296  411.656555  337.994995
# 2      0  1430.355591  469.63623  936.946838  412.068024  338.019562
# 3      0  1430.355591  469.63623  936.946838  412.068024  338.019562
# 4      0  1430.355591  469.63623  937.045288  412.275360  338.033234
#
#    HeadPosY    HeadPosZ
# 0  5.472280  356.630432
# 1  5.482665  356.590302
# 2  5.514893  356.509766
# 3  5.514893  356.509766
# 4  5.531697  356.485657

# %%
t1[t1['Count'].isin([0,1,2,3])]
# Out:
#      Count        realx       realy        EyeX        EyeY    HeadPosX  \
# 0        0  1430.355591  469.636230  936.891296  411.656555  337.998352
# 1        0  1430.355591  469.636230  936.891296  411.656555  337.994995
# 2        0  1430.355591  469.636230  936.946838  412.068024  338.019562
# 3        0  1430.355591  469.636230  936.946838  412.068024  338.019562
# 4        0  1430.355591  469.636230  937.045288  412.275360  338.033234
# ..     ...          ...         ...         ...         ...         ...
# 710      3   848.438599  630.906616  845.988586  625.249207  334.424469
# 711      3   848.438599  630.906616  845.988586  625.249207  334.392914
# 712      3   848.438599  630.906616  845.876770  625.215210  334.392914
# 713      3   848.438599  630.906616  845.876770  625.215210  334.375153
# 714      3   848.438599  630.906616  845.714905  625.204895  334.375153
#
#      HeadPosY    HeadPosZ
# 0    5.472280  356.630432
# 1    5.482665  356.590302
# ...

# %%
t1[t1['realx'] > 1000]
# Out:
#       Count        realx       realy         EyeX        EyeY    HeadPosX  \
# 0         0  1430.355591  469.636230   936.891296  411.656555  337.998352
# 1         0  1430.355591  469.636230   936.891296  411.656555  337.994995
# 2         0  1430.355591  469.636230   936.946838  412.068024  338.019562
# 3         0  1430.355591  469.636230   936.946838  412.068024  338.019562
# 4         0  1430.355591  469.636230   937.045288  412.275360  338.033234
# ...     ...          ...         ...          ...         ...         ...
# 1790      9  1392.806274  570.713379  1388.627441  585.211243  334.845001
# 1791      9  1392.806274  570.713379  1388.627441  585.211243  334.880096
# 1792      9  1392.806274  570.713379  1388.600952  585.782349  334.880096
# 1793      9  1392.806274  570.713379  1388.600952  585.782349  334.829010
# 1794      9  1392.806274  570.713379  1388.362427  586.357666  334.829010
#
#       HeadPosY    HeadPosZ
# 0     5.472280  356.630432
# ...

# %%
t1['EyeX']
# Out:
# 0        936.891296
# 1        936.891296
# 2        936.946838
# 3        936.946838
# 4        937.045288
#            ...
# 1790    1388.627441
# 1791    1388.627441
# 1792    1388.600952
# 1793    1388.600952
# 1794    1388.362427
# Name: EyeX, Length: 1795, dtype: float64

# %%
t1.loc[t1['Count']==1,['EyeX','EyeY']]
# t1.loc 目录选取 t1.iloc 索引选取
# Out:
#             EyeX        EyeY
# 175  1183.919067  494.765350
# 176  1183.919067  494.765350
# 177  1183.447998  494.924347
# 178  1183.447998  494.924347
# 179  1182.876831  495.509613
# ..           ...         ...
# 350  1489.945679  269.899567
# 351  1490.930542  272.621063
# 352  1490.930542  272.621063
# 353  1492.423218  275.401398
# 354  1495.432617  278.865723
#
# [180 rows x 2 columns]
